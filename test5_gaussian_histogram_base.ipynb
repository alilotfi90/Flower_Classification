# %% [markdown]
# <a href="https://colab.research.google.com/github/alilotfi90/Flower_Classification/blob/main/test5_gaussian_histogram_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter


# !pip install efficientnet_pytorch
from zipfile import ZipFile
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn as nn
import torch.optim as optim
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from efficientnet_pytorch import EfficientNet
import torchvision.models as models




drive.mount('/content/drive')
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=ecc9d4dbbcb5941ccc64662b111a95387ab28d271a1e28f8e5c5fe0d965f4b99
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1
# Mounted at /content/drive

# %%
import zipfile


with zipfile.ZipFile('/content/drive/MyDrive/flowerimages.zip', 'r') as zip_ref:
    zip_ref.extractall('unzipped_images_flower')

# %%
from PIL import Image
import os

unzipped_folder = '/content/unzipped_images_flower/flowers'
output_folder = '/content/resized_images_flower'


os.makedirs(output_folder, exist_ok=True)

subdirectories = [d for d in os.listdir(unzipped_folder) if os.path.isdir(os.path.join(unzipped_folder, d))]

# seen = set()
for flower_category in subdirectories:
    input_folder = os.path.join(unzipped_folder, flower_category)
    output_category_folder = os.path.join(output_folder, flower_category)


    os.makedirs(output_category_folder, exist_ok=True)

    image_files = [f for f in os.listdir(input_folder) if f.endswith('.jpg')]

    for image_file in image_files:
      input_image_path = os.path.join(input_folder, image_file)
      output_image_path = os.path.join(output_category_folder, image_file)

      image = Image.open(input_image_path)

      # Ensure the image is RGB
      image = image.convert("RGB")

      # Resize the image
      target_size = (224, 224)
      image = image.resize(target_size, Image.ANTIALIAS)

      image.save(output_image_path)


from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split


max_images_per_class =60
data = []

for flower_category in subdirectories:
    category_folder = os.path.join(output_folder, flower_category)
    image_files = [f for f in os.listdir(category_folder) if f.endswith('.jpg')]
    label = subdirectories.index(flower_category)  # label = folder's name

    # Limit the number of images to max_images_per_class
    image_files = image_files[:max_images_per_class]

    for image_file in image_files:
        image_path = os.path.join(category_folder, image_file)
        data.append((image_path, label))

train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)








# from PIL import Image
# import os

# unzipped_folder = '/content/unzipped_images_flower/flowers'
# output_folder = '/content/resized_images_flower'


# os.makedirs(output_folder, exist_ok=True)

# subdirectories = [d for d in os.listdir(unzipped_folder) if os.path.isdir(os.path.join(unzipped_folder, d))]

# # seen = set()
# for flower_category in subdirectories:
#     input_folder = os.path.join(unzipped_folder, flower_category)
#     output_category_folder = os.path.join(output_folder, flower_category)


#     os.makedirs(output_category_folder, exist_ok=True)

#     image_files = [f for f in os.listdir(input_folder) if f.endswith('.jpg')]

#     for image_file in image_files:
#       input_image_path = os.path.join(input_folder, image_file)
#       output_image_path = os.path.join(output_category_folder, image_file)

#       image = Image.open(input_image_path)

#       # Ensure the image is RGB
#       image = image.convert("RGB")

#       # Resize the image
#       target_size = (224, 224)
#       image = image.resize(target_size, Image.ANTIALIAS)

#       image.save(output_image_path)


# from torchvision import transforms
# from torch.utils.data import DataLoader, Dataset
# from sklearn.model_selection import train_test_split


# max_images_per_class =60
# data = []

# for flower_category in subdirectories:
#     category_folder = os.path.join(output_folder, flower_category)
#     image_files = [f for f in os.listdir(category_folder) if f.endswith('.jpg')]
#     label = subdirectories.index(flower_category)  # label = folder's name

#     # Limit the number of images to max_images_per_class
#     image_files = image_files[:max_images_per_class]

#     for image_file in image_files:
#         image_path = os.path.join(category_folder, image_file)
#         data.append((image_path, label))

# train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
# Out:
# <ipython-input-3-4b2652e337d8>:33: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   image = image.resize(target_size, Image.ANTIALIAS)

# %%
# from torch.utils.data import DataLoader, Dataset
# from sklearn.model_selection import train_test_split
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# class CustomDataset(Dataset):
#     def __init__(self, data, transform=None):
#         self.data = data
#         self.transform = transform
#         self.grayscale_count = 0  # Adding a counter for grayscale images

#     def __len__(self):
#         return len(self.data)

#     def __getitem__(self, idx):
#         image_path, label = self.data[idx]
#         image = Image.open(image_path)

#         # we don't really need the following, we changed rare grayscale images to rgb when feeding to the colour_model
#         # Check and convert grayscale images
#         # if image.mode != 'RGB':
#         #     image = image.convert('RGB')

#         if self.transform:
#             image = self.transform(image)
#         return image, label

# class HistEqualize(object):
#     def __call__(self, img):
#         return F.equalize(img)

#     def __repr__(self):
#         return self.__class__.__name__ + '()'

# #base transform
# transform_gray = transforms.Compose([
#     transforms.Grayscale(num_output_channels=1),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485], std=[0.229])
# ])
# # Gaussian Blur Transformation
# transform_gaussian = transforms.Compose([
#     transforms.Grayscale(num_output_channels=1),
#     transforms.GaussianBlur(5),  # Kernel size of 5, you can adjust as needed
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485], std=[0.229])
# ])

# # Histogram Equalization Transformation
# transform_hist_eq = transforms.Compose([
#     transforms.Grayscale(num_output_channels=1),
#     HistEqualize(),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485], std=[0.229])
# ])

# # Data Loaders for the new transformations
# train_loader_gray = DataLoader(CustomDataset(train_data, transform=transform_gray), batch_size=32, shuffle=True)
# test_loader_gray = DataLoader(CustomDataset(test_data, transform=transform_gray), batch_size=32)
# train_loader_gaussian = DataLoader(CustomDataset(train_data, transform=transform_gaussian), batch_size=32, shuffle=True)
# test_loader_gaussian = DataLoader(CustomDataset(test_data, transform=transform_gaussian), batch_size=32)
# train_loader_hist_eq = DataLoader(CustomDataset(train_data, transform=transform_hist_eq), batch_size=32, shuffle=True)
# test_loader_hist_eq = DataLoader(CustomDataset(test_data, transform=transform_hist_eq), batch_size=32)


from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import torchvision.transforms.functional as F
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform
        self.grayscale_count = 0  # Adding a counter for grayscale images

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path)

        # we don't really need the following, we changed rare grayscale images to rgb when feeding to the colour_model
        # Check and convert grayscale images
        # if image.mode != 'RGB':
        #     image = image.convert('RGB')

        if self.transform:
            image = self.transform(image)
        return image, label

class HistEqualize(object):
    def __call__(self, img):
        return F.equalize(img)

    def __repr__(self):
        return self.__class__.__name__ + '()'

#base transform
transform_gray = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485], std=[0.229])
])
# Gaussian Blur Transformation
transform_gaussian = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.GaussianBlur(5),  # Kernel size of 5, you can adjust as needed
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485], std=[0.229])
])

# Histogram Equalization Transformation
transform_hist_eq = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    HistEqualize(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485], std=[0.229])
])

# Data Loaders for the new transformations
train_loader_gray = DataLoader(CustomDataset(train_data, transform=transform_gray), batch_size=32, shuffle=True)
test_loader_gray = DataLoader(CustomDataset(test_data, transform=transform_gray), batch_size=32)
train_loader_gaussian = DataLoader(CustomDataset(train_data, transform=transform_gaussian), batch_size=32, shuffle=True)
test_loader_gaussian = DataLoader(CustomDataset(test_data, transform=transform_gaussian), batch_size=32)
train_loader_hist_eq = DataLoader(CustomDataset(train_data, transform=transform_hist_eq), batch_size=32, shuffle=True)
test_loader_hist_eq = DataLoader(CustomDataset(test_data, transform=transform_hist_eq), batch_size=32)

class CustomEfficientNet(nn.Module):
    def __init__(self, pretrained_model_name='efficientnet-b0', num_classes=16):
        super(CustomEfficientNet, self).__init__()
        self.embedding = nn.Conv2d(1, 3, kernel_size=1, stride=1, padding=0)
        self.eff_net = EfficientNet.from_pretrained(pretrained_model_name, num_classes=num_classes)

    def forward(self, x):
        x = self.embedding(x)
        x = self.eff_net(x)
        return x
model_gray = CustomEfficientNet().to(device)  # For regular grayscale
model_gray_gaussian = CustomEfficientNet().to(device)  # For Gaussian-blurred grayscale
model_gray_hist_eq = CustomEfficientNet().to(device)  # For histogram-equalized grayscale


optimizer_gray = optim.SGD(model_gray.parameters(), lr=0.001, momentum=0.9)
optimizer_gray_gaussian = optim.SGD(model_gray_gaussian.parameters(), lr=0.001, momentum=0.9)
optimizer_gray_hist_eq = optim.SGD(model_gray_hist_eq.parameters(), lr=0.001, momentum=0.9)

criterion = nn.CrossEntropyLoss()

def train_test_model(model, train_loader, test_loader, optimizer, criterion, epochs_list, model_name):
    accuracies = []
    cumulative_epochs = 0
    for epochs in epochs_list:
        cumulative_epochs += epochs
        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            for i, data in enumerate(train_loader, 0):
                inputs, labels = data[0].to(device), data[1].to(device)
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                if i % 10 == 9:
                    print(f'[{cumulative_epochs + epoch + 1}, {i + 1}] loss: {running_loss / 10:.3f}')
                    running_loss = 0.0

            model.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                for data in test_loader:
                    images, labels = data[0].to(device), data[1].to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()

            accuracy = 100 * correct / total
            accuracies.append(accuracy)
            print(f'Accuracy of {model_name} after {cumulative_epochs + epoch + 1} epochs on test images: {accuracy:.2f}%')
    return accuracies
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 313MB/s]
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0

# %%
# class CustomEfficientNet(nn.Module):
#     def __init__(self, pretrained_model_name='efficientnet-b0', num_classes=16):
#         super(CustomEfficientNet, self).__init__()
#         self.embedding = nn.Conv2d(1, 3, kernel_size=1, stride=1, padding=0)
#         self.eff_net = EfficientNet.from_pretrained(pretrained_model_name, num_classes=num_classes)

#     def forward(self, x):
#         x = self.embedding(x)
#         x = self.eff_net(x)
#         return x
# model_gray = CustomEfficientNet().to(device)  # For regular grayscale
# model_gray_gaussian = CustomEfficientNet().to(device)  # For Gaussian-blurred grayscale
# model_gray_hist_eq = CustomEfficientNet().to(device)  # For histogram-equalized grayscale


# optimizer_gray = optim.SGD(model_gray.parameters(), lr=0.001, momentum=0.9)
# optimizer_gray_gaussian = optim.SGD(model_gray_gaussian.parameters(), lr=0.001, momentum=0.9)
# optimizer_gray_hist_eq = optim.SGD(model_gray_hist_eq.parameters(), lr=0.001, momentum=0.9)

# criterion = nn.CrossEntropyLoss()

# def train_test_model(model, train_loader, test_loader, optimizer, criterion, epochs_list, model_name):
#     accuracies = []
#     cumulative_epochs = 0
#     for epochs in epochs_list:
#         cumulative_epochs += epochs
#         for epoch in range(epochs):
#             model.train()
#             running_loss = 0.0
#             for i, data in enumerate(train_loader, 0):
#                 inputs, labels = data[0].to(device), data[1].to(device)
#                 optimizer.zero_grad()
#                 outputs = model(inputs)
#                 loss = criterion(outputs, labels)
#                 loss.backward()
#                 optimizer.step()
#                 running_loss += loss.item()
#                 if i % 10 == 9:
#                     print(f'[{cumulative_epochs + epoch + 1}, {i + 1}] loss: {running_loss / 10:.3f}')
#                     running_loss = 0.0

#             model.eval()
#             correct = 0
#             total = 0
#             with torch.no_grad():
#                 for data in test_loader:
#                     images, labels = data[0].to(device), data[1].to(device)
#                     outputs = model(images)
#                     _, predicted = torch.max(outputs.data, 1)
#                     total += labels.size(0)
#                     correct += (predicted == labels).sum().item()

#             accuracy = 100 * correct / total
#             accuracies.append(accuracy)
#             print(f'Accuracy of {model_name} after {cumulative_epochs + epoch + 1} epochs on test images: {accuracy:.2f}%')
#     return accuracies
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 432MB/s]
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0
# Loaded pretrained weights for efficientnet-b0

# %%
# epochs_list = [10, 20,30,40,50,60]
# # Training and geting accuracies

# train_loader_gray = DataLoader(CustomDataset(train_data, transform=transform_gray), batch_size=32, shuffle=True)
# test_loader_gray = DataLoader(CustomDataset(test_data, transform=transform_gray), batch_size=32)
# train_loader_gaussian = DataLoader(CustomDataset(train_data, transform=transform_gaussian), batch_size=32, shuffle=True)
# test_loader_gaussian = DataLoader(CustomDataset(test_data, transform=transform_gaussian), batch_size=32)
# train_loader_hist_eq = DataLoader(CustomDataset(train_data, transform=transform_hist_eq), batch_size=32, shuffle=True)
# test_loader_hist_eq = DataLoader(CustomDataset(test_data, transform=transform_hist_eq), batch_size=32)

# accuracies_gray = train_test_model(model_gray, train_loader_gray, test_loader_gray, optimizer_gray, criterion, epochs_list, "Grayscale Model")
# accuracies_gaussian = train_test_model(model_gray_gaussian, train_loader_gaussian, test_loader_gaussian, optimizer_gray, criterion, epochs_list, "Gaussian Model")
# accuracies_hist_eq = train_test_model(model_gray_hist_eq, train_loader_hist_eq, test_loader_hist_eq, optimizer_gray, criterion, epochs_list, "Histogram Equalization Model")


# df = pd.DataFrame({
#     'Epochs': [sum(epochs_list[:i+1]) for i in range(len(epochs_list))],
#     'Grayscale_Model_Accuracy': accuracies_gray,
#     'Gaussian_Model_Accuracy': accuracies_gaussian,
#     'Histogram_Model_Accuracy': accuracies_hist_eq,
# })

# import matplotlib.pyplot as plt

# fig, ax =plt.subplots(figsize=(12,4))
# ax.axis('tight')
# ax.axis('off')
# the_table = ax.table(cellText=df.values,colLabels=df.columns,loc='center')
# the_table.auto_set_font_size(False)
# the_table.set_fontsize(10)
# plt.savefig("/content/drive/MyDrive/model_accuracies.jpeg")


epochs_list = [10, 20,30]
# Training and geting accuracies

train_loader_gray = DataLoader(CustomDataset(train_data, transform=transform_gray), batch_size=32, shuffle=True)
test_loader_gray = DataLoader(CustomDataset(test_data, transform=transform_gray), batch_size=32)
train_loader_gaussian = DataLoader(CustomDataset(train_data, transform=transform_gaussian), batch_size=32, shuffle=True)
test_loader_gaussian = DataLoader(CustomDataset(test_data, transform=transform_gaussian), batch_size=32)
train_loader_hist_eq = DataLoader(CustomDataset(train_data, transform=transform_hist_eq), batch_size=32, shuffle=True)
test_loader_hist_eq = DataLoader(CustomDataset(test_data, transform=transform_hist_eq), batch_size=32)

# accuracies_hist_eq = train_test_model(model_gray_hist_eq, train_loader_hist_eq, test_loader_hist_eq, optimizer_gray, criterion, epochs_list, "Histogram Equalization Model")
# accuracies_gaussian = train_test_model(model_gray_gaussian, train_loader_gaussian, test_loader_gaussian, optimizer_gray, criterion, epochs_list, "Gaussian Model")


accuracies_hist_eq = train_test_model(model_gray_hist_eq, train_loader_hist_eq, test_loader_hist_eq, optimizer_gray_hist_eq, criterion, epochs_list, "Histogram Equalization Model")
accuracies_gaussian = train_test_model(model_gray_gaussian, train_loader_gaussian, test_loader_gaussian, optimizer_gray_gaussian, criterion, epochs_list, "Gaussian Model")
accuracies_gray = train_test_model(model_gray, train_loader_gray, test_loader_gray, optimizer_gray, criterion, epochs_list, "Grayscale Model")




# df = pd.DataFrame({
#     'Epochs': [sum(epochs_list[:i+1]) for i in range(len(epochs_list))],
#     'Grayscale_Model_Accuracy': accuracies_gray,
#     'Gaussian_Model_Accuracy': accuracies_gaussian,
#     'Histogram_Model_Accuracy': accuracies_hist_eq,
# })

# import matplotlib.pyplot as plt

# fig, ax =plt.subplots(figsize=(12,4))
# ax.axis('tight')
# ax.axis('off')
# the_table = ax.table(cellText=df.values,colLabels=df.columns,loc='center')
# the_table.auto_set_font_size(False)
# the_table.set_fontsize(10)
# plt.savefig("/content/drive/MyDrive/model_accuracies.jpeg")
# Out:
# [11, 10] loss: 2.783
# [11, 20] loss: 2.732
# Accuracy of Histogram Equalization Model after 11 epochs on test images: 6.77%
# [12, 10] loss: 2.674
# [12, 20] loss: 2.609
# Accuracy of Histogram Equalization Model after 12 epochs on test images: 11.46%
# [13, 10] loss: 2.528
# [13, 20] loss: 2.465
# Accuracy of Histogram Equalization Model after 13 epochs on test images: 18.23%
# [14, 10] loss: 2.357
# [14, 20] loss: 2.364
# Accuracy of Histogram Equalization Model after 14 epochs on test images: 18.23%
# [15, 10] loss: 2.259
# [15, 20] loss: 2.192
# Accuracy of Histogram Equalization Model after 15 epochs on test images: 23.96%
# [16, 10] loss: 2.120
# [16, 20] loss: 2.062
# Accuracy of Histogram Equalization Model after 16 epochs on test images: 27.60%
# [17, 10] loss: 1.954
# [17, 20] loss: 1.864
# Accuracy of Histogram Equalization Model after 17 epochs on test images: 32.29%
# [18, 10] loss: 1.786
# [18, 20] loss: 1.780
# Accuracy of Histogram Equalization Model after 18 epochs on test images: 35.94%
# [19, 10] loss: 1.704
# [19, 20] loss: 1.620
# Accuracy of Histogram Equalization Model after 19 epochs on test images: 43.23%
# [20, 10] loss: 1.590
# [20, 20] loss: 1.499
# Accuracy of Histogram Equalization Model after 20 epochs on test images: 52.08%
# [31, 10] loss: 1.432
# [31, 20] loss: 1.413
# Accuracy of Histogram Equalization Model after 31 epochs on test images: 60.42%
# [32, 10] loss: 1.351
# [32, 20] loss: 1.306
# Accuracy of Histogram Equalization Model after 32 epochs on test images: 63.02%
# [33, 10] loss: 1.236
# [33, 20] loss: 1.229
# Accuracy of Histogram Equalization Model after 33 epochs on test images: 68.23%
# [34, 10] loss: 1.144
# [34, 20] loss: 1.135
# Accuracy of Histogram Equalization Model after 34 epochs on test images: 69.79%
# [35, 10] loss: 1.131
# [35, 20] loss: 1.015
# Accuracy of Histogram Equalization Model after 35 epochs on test images: 70.83%
# [36, 10] loss: 1.008
# [36, 20] loss: 0.992
# Accuracy of Histogram Equalization Model after 36 epochs on test images: 72.92%
# [37, 10] loss: 0.937
# [37, 20] loss: 0.919
# Accuracy of Histogram Equalization Model after 37 epochs on test images: 72.92%
# [38, 10] loss: 0.824
# [38, 20] loss: 0.841
# Accuracy of Histogram Equalization Model after 38 epochs on test images: 73.44%
# [39, 10] loss: 0.847
# [39, 20] loss: 0.720
# Accuracy of Histogram Equalization Model after 39 epochs on test images: 72.92%
# [40, 10] loss: 0.789
# [40, 20] loss: 0.745
# Accuracy of Histogram Equalization Model after 40 epochs on test images: 73.44%
# [41, 10] loss: 0.690
# [41, 20] loss: 0.705
# Accuracy of Histogram Equalization Model after 41 epochs on test images: 71.35%
# [42, 10] loss: 0.698
# [42, 20] loss: 0.608
# Accuracy of Histogram Equalization Model after 42 epochs on test images: 73.44%
# [43, 10] loss: 0.636
# [43, 20] loss: 0.619
# Accuracy of Histogram Equalization Model after 43 epochs on test images: 76.04%
# [44, 10] loss: 0.564
# [44, 20] loss: 0.565
# Accuracy of Histogram Equalization Model after 44 epochs on test images: 73.44%
# [45, 10] loss: 0.587
# [45, 20] loss: 0.493
# Accuracy of Histogram Equalization Model after 45 epochs on test images: 73.96%
# [46, 10] loss: 0.503
# [46, 20] loss: 0.499
# Accuracy of Histogram Equalization Model after 46 epochs on test images: 75.00%
# [47, 10] loss: 0.472
# [47, 20] loss: 0.469
# Accuracy of Histogram Equalization Model after 47 epochs on test images: 75.52%
# [48, 10] loss: 0.404
# [48, 20] loss: 0.466
# Accuracy of Histogram Equalization Model after 48 epochs on test images: 74.48%
# [49, 10] loss: 0.414
# [49, 20] loss: 0.432
# Accuracy of Histogram Equalization Model after 49 epochs on test images: 75.00%
# [50, 10] loss: 0.454
# [50, 20] loss: 0.386
# Accuracy of Histogram Equalization Model after 50 epochs on test images: 76.04%
# [61, 10] loss: 0.358
# [61, 20] loss: 0.367
# Accuracy of Histogram Equalization Model after 61 epochs on test images: 76.04%
# [62, 10] loss: 0.345
# [62, 20] loss: 0.353
# Accuracy of Histogram Equalization Model after 62 epochs on test images: 77.08%
# [63, 10] loss: 0.328
# [63, 20] loss: 0.314
# Accuracy of Histogram Equalization Model after 63 epochs on test images: 76.04%
# [64, 10] loss: 0.351
# [64, 20] loss: 0.281
# Accuracy of Histogram Equalization Model after 64 epochs on test images: 76.56%
# [65, 10] loss: 0.293
# [65, 20] loss: 0.260
# Accuracy of Histogram Equalization Model after 65 epochs on test images: 76.04%
# [66, 10] loss: 0.331
# [66, 20] loss: 0.274
# Accuracy of Histogram Equalization Model after 66 epochs on test images: 76.56%
# [67, 10] loss: 0.313
# [67, 20] loss: 0.290
# Accuracy of Histogram Equalization Model after 67 epochs on test images: 76.04%
# [68, 10] loss: 0.233
# [68, 20] loss: 0.268
# Accuracy of Histogram Equalization Model after 68 epochs on test images: 76.04%
# [69, 10] loss: 0.244
# [69, 20] loss: 0.253
# Accuracy of Histogram Equalization Model after 69 epochs on test images: 76.04%
# [70, 10] loss: 0.236
# [70, 20] loss: 0.246
# Accuracy of Histogram Equalization Model after 70 epochs on test images: 76.56%
# [71, 10] loss: 0.203
# [71, 20] loss: 0.210
# Accuracy of Histogram Equalization Model after 71 epochs on test images: 76.56%
# [72, 10] loss: 0.212
# [72, 20] loss: 0.178
# Accuracy of Histogram Equalization Model after 72 epochs on test images: 77.08%
# [73, 10] loss: 0.192
# [73, 20] loss: 0.212
# Accuracy of Histogram Equalization Model after 73 epochs on test images: 76.56%
# [74, 10] loss: 0.180
# [74, 20] loss: 0.193
# Accuracy of Histogram Equalization Model after 74 epochs on test images: 76.04%
# [75, 10] loss: 0.172
# [75, 20] loss: 0.196
# Accuracy of Histogram Equalization Model after 75 epochs on test images: 76.56%
# [76, 10] loss: 0.161
# [76, 20] loss: 0.177
# Accuracy of Histogram Equalization Model after 76 epochs on test images: 78.12%
# [77, 10] loss: 0.151
# [77, 20] loss: 0.151
# Accuracy of Histogram Equalization Model after 77 epochs on test images: 77.08%
# [78, 10] loss: 0.153
# [78, 20] loss: 0.183
# Accuracy of Histogram Equalization Model after 78 epochs on test images: 77.60%
# [79, 10] loss: 0.154
# [79, 20] loss: 0.146
# Accuracy of Histogram Equalization Model after 79 epochs on test images: 77.08%
# [80, 10] loss: 0.136
# [80, 20] loss: 0.144
# Accuracy of Histogram Equalization Model after 80 epochs on test images: 77.08%
# [81, 10] loss: 0.119
# [81, 20] loss: 0.141
# Accuracy of Histogram Equalization Model after 81 epochs on test images: 77.08%
# [82, 10] loss: 0.116
# [82, 20] loss: 0.115
# Accuracy of Histogram Equalization Model after 82 epochs on test images: 77.08%
# [83, 10] loss: 0.104
# [83, 20] loss: 0.144
# Accuracy of Histogram Equalization Model after 83 epochs on test images: 77.08%
# [84, 10] loss: 0.132
# [84, 20] loss: 0.107
# Accuracy of Histogram Equalization Model after 84 epochs on test images: 77.60%
# [85, 10] loss: 0.117
# [85, 20] loss: 0.088
# Accuracy of Histogram Equalization Model after 85 epochs on test images: 77.60%
# [86, 10] loss: 0.082
# [86, 20] loss: 0.102
# Accuracy of Histogram Equalization Model after 86 epochs on test images: 77.60%
# [87, 10] loss: 0.096
# [87, 20] loss: 0.107
# Accuracy of Histogram Equalization Model after 87 epochs on test images: 77.08%
# [88, 10] loss: 0.088
# [88, 20] loss: 0.123
# Accuracy of Histogram Equalization Model after 88 epochs on test images: 77.08%
# [89, 10] loss: 0.110
# [89, 20] loss: 0.105
# Accuracy of Histogram Equalization Model after 89 epochs on test images: 77.08%
# [90, 10] loss: 0.106
# [90, 20] loss: 0.084
# Accuracy of Histogram Equalization Model after 90 epochs on test images: 77.60%
# [11, 10] loss: 2.778
# [11, 20] loss: 2.764
# Accuracy of Gaussian Model after 11 epochs on test images: 10.94%
# [12, 10] loss: 2.696
# [12, 20] loss: 2.647
# Accuracy of Gaussian Model after 12 epochs on test images: 22.40%
# [13, 10] loss: 2.549
# [13, 20] loss: 2.530
# Accuracy of Gaussian Model after 13 epochs on test images: 29.69%
# [14, 10] loss: 2.440
# [14, 20] loss: 2.393
# Accuracy of Gaussian Model after 14 epochs on test images: 31.77%
# [15, 10] loss: 2.317
# [15, 20] loss: 2.284
# Accuracy of Gaussian Model after 15 epochs on test images: 38.02%
# [16, 10] loss: 2.180
# [16, 20] loss: 2.132
# Accuracy of Gaussian Model after 16 epochs on test images: 45.31%
# [17, 10] loss: 2.064
# [17, 20] loss: 1.994
# Accuracy of Gaussian Model after 17 epochs on test images: 48.44%
# [18, 10] loss: 1.926
# [18, 20] loss: 1.872
# Accuracy of Gaussian Model after 18 epochs on test images: 52.60%
# [19, 10] loss: 1.764
# [19, 20] loss: 1.765
# Accuracy of Gaussian Model after 19 epochs on test images: 54.17%
# [20, 10] loss: 1.664
# [20, 20] loss: 1.643
# Accuracy of Gaussian Model after 20 epochs on test images: 59.38%
# [31, 10] loss: 1.574
# [31, 20] loss: 1.528
# Accuracy of Gaussian Model after 31 epochs on test images: 61.46%
# [32, 10] loss: 1.494
# [32, 20] loss: 1.416
# Accuracy of Gaussian Model after 32 epochs on test images: 64.06%
# [33, 10] loss: 1.337
# [33, 20] loss: 1.331
# Accuracy of Gaussian Model after 33 epochs on test images: 65.10%
# [34, 10] loss: 1.286
# [34, 20] loss: 1.269
# Accuracy of Gaussian Model after 34 epochs on test images: 66.15%
# [35, 10] loss: 1.227
# [35, 20] loss: 1.148
# Accuracy of Gaussian Model after 35 epochs on test images: 70.31%
# [36, 10] loss: 1.045
# [36, 20] loss: 1.127
# Accuracy of Gaussian Model after 36 epochs on test images: 69.79%
# [37, 10] loss: 1.118
# [37, 20] loss: 1.037
# Accuracy of Gaussian Model after 37 epochs on test images: 71.35%
# [38, 10] loss: 1.022
# [38, 20] loss: 0.978
# Accuracy of Gaussian Model after 38 epochs on test images: 72.40%
# [39, 10] loss: 0.956
# [39, 20] loss: 0.896
# Accuracy of Gaussian Model after 39 epochs on test images: 72.92%
# [40, 10] loss: 0.871
# [40, 20] loss: 0.930
# Accuracy of Gaussian Model after 40 epochs on test images: 75.52%
# [41, 10] loss: 0.803
# [41, 20] loss: 0.838
# Accuracy of Gaussian Model after 41 epochs on test images: 75.52%
# [42, 10] loss: 0.804
# [42, 20] loss: 0.732
# Accuracy of Gaussian Model after 42 epochs on test images: 74.48%
# [43, 10] loss: 0.675
# [43, 20] loss: 0.735
# Accuracy of Gaussian Model after 43 epochs on test images: 76.56%
# [44, 10] loss: 0.632
# [44, 20] loss: 0.730
# Accuracy of Gaussian Model after 44 epochs on test images: 73.44%
# [45, 10] loss: 0.644
# [45, 20] loss: 0.668
# Accuracy of Gaussian Model after 45 epochs on test images: 75.52%
# [46, 10] loss: 0.595
# [46, 20] loss: 0.641
# Accuracy of Gaussian Model after 46 epochs on test images: 77.60%
# [47, 10] loss: 0.586
# [47, 20] loss: 0.570
# Accuracy of Gaussian Model after 47 epochs on test images: 77.60%
# [48, 10] loss: 0.542
# [48, 20] loss: 0.594
# Accuracy of Gaussian Model after 48 epochs on test images: 75.00%
# [49, 10] loss: 0.576
# [49, 20] loss: 0.503
# Accuracy of Gaussian Model after 49 epochs on test images: 77.60%
# [50, 10] loss: 0.542
# [50, 20] loss: 0.460
# Accuracy of Gaussian Model after 50 epochs on test images: 78.65%
# [61, 10] loss: 0.496
# [61, 20] loss: 0.434
# Accuracy of Gaussian Model after 61 epochs on test images: 76.04%
# [62, 10] loss: 0.467
# [62, 20] loss: 0.423
# Accuracy of Gaussian Model after 62 epochs on test images: 77.08%
# [63, 10] loss: 0.402
# [63, 20] loss: 0.441
# Accuracy of Gaussian Model after 63 epochs on test images: 77.60%
# [64, 10] loss: 0.415
# [64, 20] loss: 0.428
# Accuracy of Gaussian Model after 64 epochs on test images: 78.65%
# [65, 10] loss: 0.392
# [65, 20] loss: 0.385
# Accuracy of Gaussian Model after 65 epochs on test images: 78.12%
# [66, 10] loss: 0.377
# [66, 20] loss: 0.375
# Accuracy of Gaussian Model after 66 epochs on test images: 77.08%
# [67, 10] loss: 0.345
# [67, 20] loss: 0.336
# Accuracy of Gaussian Model after 67 epochs on test images: 76.56%
# [68, 10] loss: 0.324
# [68, 20] loss: 0.319
# Accuracy of Gaussian Model after 68 epochs on test images: 77.60%
# [69, 10] loss: 0.320
# [69, 20] loss: 0.361
# Accuracy of Gaussian Model after 69 epochs on test images: 76.56%
# [70, 10] loss: 0.298
# [70, 20] loss: 0.298
# Accuracy of Gaussian Model after 70 epochs on test images: 79.17%
# [71, 10] loss: 0.279
# [71, 20] loss: 0.303
# Accuracy of Gaussian Model after 71 epochs on test images: 78.12%
# [72, 10] loss: 0.283
# [72, 20] loss: 0.271
# Accuracy of Gaussian Model after 72 epochs on test images: 78.12%
# [73, 10] loss: 0.272
# [73, 20] loss: 0.271
# Accuracy of Gaussian Model after 73 epochs on test images: 78.12%
# [74, 10] loss: 0.250
# [74, 20] loss: 0.233
# Accuracy of Gaussian Model after 74 epochs on test images: 78.12%
# [75, 10] loss: 0.240
# [75, 20] loss: 0.227
# Accuracy of Gaussian Model after 75 epochs on test images: 79.17%
# [76, 10] loss: 0.218
# [76, 20] loss: 0.279
# Accuracy of Gaussian Model after 76 epochs on test images: 79.69%
# [77, 10] loss: 0.217
# [77, 20] loss: 0.232
# Accuracy of Gaussian Model after 77 epochs on test images: 80.21%
# [78, 10] loss: 0.208
# [78, 20] loss: 0.225
# Accuracy of Gaussian Model after 78 epochs on test images: 79.17%
# [79, 10] loss: 0.204
# [79, 20] loss: 0.205
# Accuracy of Gaussian Model after 79 epochs on test images: 78.65%
# [80, 10] loss: 0.223
# [80, 20] loss: 0.214
# Accuracy of Gaussian Model after 80 epochs on test images: 78.12%
# [81, 10] loss: 0.171
# [81, 20] loss: 0.170
# Accuracy of Gaussian Model after 81 epochs on test images: 78.65%
# [82, 10] loss: 0.191
# [82, 20] loss: 0.164
# Accuracy of Gaussian Model after 82 epochs on test images: 77.60%
# [83, 10] loss: 0.178
# [83, 20] loss: 0.202
# Accuracy of Gaussian Model after 83 epochs on test images: 81.77%
# [84, 10] loss: 0.180
# [84, 20] loss: 0.149
# Accuracy of Gaussian Model after 84 epochs on test images: 78.12%
# [85, 10] loss: 0.161
# [85, 20] loss: 0.164
# Accuracy of Gaussian Model after 85 epochs on test images: 80.21%
# [86, 10] loss: 0.149
# [86, 20] loss: 0.159
# Accuracy of Gaussian Model after 86 epochs on test images: 79.17%
# [87, 10] loss: 0.151
# [87, 20] loss: 0.157
# Accuracy of Gaussian Model after 87 epochs on test images: 80.21%
# [88, 10] loss: 0.138
# [88, 20] loss: 0.141
# Accuracy of Gaussian Model after 88 epochs on test images: 80.73%
# [89, 10] loss: 0.138
# [89, 20] loss: 0.149
# Accuracy of Gaussian Model after 89 epochs on test images: 80.73%
# [90, 10] loss: 0.143
# [90, 20] loss: 0.124
# Accuracy of Gaussian Model after 90 epochs on test images: 79.17%
# [11, 10] loss: 2.806
# [11, 20] loss: 2.768
# Accuracy of Grayscale Model after 11 epochs on test images: 9.90%
# [12, 10] loss: 2.686
# [12, 20] loss: 2.636
# Accuracy of Grayscale Model after 12 epochs on test images: 19.79%
# [13, 10] loss: 2.532
# [13, 20] loss: 2.463
# Accuracy of Grayscale Model after 13 epochs on test images: 30.21%
# [14, 10] loss: 2.389
# [14, 20] loss: 2.339
# Accuracy of Grayscale Model after 14 epochs on test images: 39.06%
# [15, 10] loss: 2.240
# [15, 20] loss: 2.166
# Accuracy of Grayscale Model after 15 epochs on test images: 42.71%
# [16, 10] loss: 2.074
# [16, 20] loss: 2.059
# Accuracy of Grayscale Model after 16 epochs on test images: 49.48%
# [17, 10] loss: 1.951
# [17, 20] loss: 1.898
# Accuracy of Grayscale Model after 17 epochs on test images: 51.56%
# [18, 10] loss: 1.785
# [18, 20] loss: 1.746
# Accuracy of Grayscale Model after 18 epochs on test images: 56.25%
# [19, 10] loss: 1.688
# [19, 20] loss: 1.628
# Accuracy of Grayscale Model after 19 epochs on test images: 55.73%
# [20, 10] loss: 1.543
# [20, 20] loss: 1.460
# Accuracy of Grayscale Model after 20 epochs on test images: 60.94%
# [31, 10] loss: 1.434
# [31, 20] loss: 1.473
# Accuracy of Grayscale Model after 31 epochs on test images: 61.46%
# [32, 10] loss: 1.360
# [32, 20] loss: 1.226
# Accuracy of Grayscale Model after 32 epochs on test images: 67.19%
# [33, 10] loss: 1.285
# [33, 20] loss: 1.113
# Accuracy of Grayscale Model after 33 epochs on test images: 67.71%
# [34, 10] loss: 1.102
# [34, 20] loss: 1.112
# Accuracy of Grayscale Model after 34 epochs on test images: 69.27%
# [35, 10] loss: 1.014
# [35, 20] loss: 1.092
# Accuracy of Grayscale Model after 35 epochs on test images: 68.75%
# [36, 10] loss: 0.940
# [36, 20] loss: 0.974
# Accuracy of Grayscale Model after 36 epochs on test images: 69.27%
# [37, 10] loss: 0.892
# [37, 20] loss: 0.868
# Accuracy of Grayscale Model after 37 epochs on test images: 73.44%
# [38, 10] loss: 0.861
# [38, 20] loss: 0.784
# Accuracy of Grayscale Model after 38 epochs on test images: 72.92%
# [39, 10] loss: 0.779
# [39, 20] loss: 0.757
# Accuracy of Grayscale Model after 39 epochs on test images: 73.44%
# [40, 10] loss: 0.699
# [40, 20] loss: 0.704
# Accuracy of Grayscale Model after 40 epochs on test images: 72.92%
# [41, 10] loss: 0.715
# [41, 20] loss: 0.666
# Accuracy of Grayscale Model after 41 epochs on test images: 75.52%
# [42, 10] loss: 0.599
# [42, 20] loss: 0.623
# Accuracy of Grayscale Model after 42 epochs on test images: 74.48%
# [43, 10] loss: 0.599
# [43, 20] loss: 0.618
# Accuracy of Grayscale Model after 43 epochs on test images: 75.52%
# [44, 10] loss: 0.598
# [44, 20] loss: 0.503
# Accuracy of Grayscale Model after 44 epochs on test images: 76.04%
# [45, 10] loss: 0.519
# [45, 20] loss: 0.516
# Accuracy of Grayscale Model after 45 epochs on test images: 75.52%
# [46, 10] loss: 0.498
# [46, 20] loss: 0.495
# Accuracy of Grayscale Model after 46 epochs on test images: 76.04%
# [47, 10] loss: 0.472
# [47, 20] loss: 0.465
# Accuracy of Grayscale Model after 47 epochs on test images: 74.48%
# [48, 10] loss: 0.439
# [48, 20] loss: 0.421
# Accuracy of Grayscale Model after 48 epochs on test images: 75.00%
# [49, 10] loss: 0.422
# [49, 20] loss: 0.422
# Accuracy of Grayscale Model after 49 epochs on test images: 77.08%
# [50, 10] loss: 0.409
# [50, 20] loss: 0.390
# Accuracy of Grayscale Model after 50 epochs on test images: 77.60%
# [61, 10] loss: 0.354
# [61, 20] loss: 0.330
# Accuracy of Grayscale Model after 61 epochs on test images: 76.56%
# [62, 10] loss: 0.337
# [62, 20] loss: 0.340
# Accuracy of Grayscale Model after 62 epochs on test images: 77.08%
# [63, 10] loss: 0.313
# [63, 20] loss: 0.314
# Accuracy of Grayscale Model after 63 epochs on test images: 77.60%
# [64, 10] loss: 0.297
# [64, 20] loss: 0.311
# Accuracy of Grayscale Model after 64 epochs on test images: 77.60%
# [65, 10] loss: 0.320
# [65, 20] loss: 0.270
# Accuracy of Grayscale Model after 65 epochs on test images: 77.60%
# [66, 10] loss: 0.281
# [66, 20] loss: 0.253
# Accuracy of Grayscale Model after 66 epochs on test images: 77.60%
# [67, 10] loss: 0.248
# [67, 20] loss: 0.274
# Accuracy of Grayscale Model after 67 epochs on test images: 77.60%
# [68, 10] loss: 0.230
# [68, 20] loss: 0.276
# Accuracy of Grayscale Model after 68 epochs on test images: 78.65%
# [69, 10] loss: 0.211
# [69, 20] loss: 0.236
# Accuracy of Grayscale Model after 69 epochs on test images: 79.69%
# [70, 10] loss: 0.237
# [70, 20] loss: 0.189
# Accuracy of Grayscale Model after 70 epochs on test images: 79.17%
# [71, 10] loss: 0.166
# [71, 20] loss: 0.207
# Accuracy of Grayscale Model after 71 epochs on test images: 80.21%
# [72, 10] loss: 0.199
# [72, 20] loss: 0.208
# Accuracy of Grayscale Model after 72 epochs on test images: 78.65%
# [73, 10] loss: 0.205
# [73, 20] loss: 0.157
# Accuracy of Grayscale Model after 73 epochs on test images: 79.17%
# [74, 10] loss: 0.188
# [74, 20] loss: 0.172
# Accuracy of Grayscale Model after 74 epochs on test images: 79.69%
# [75, 10] loss: 0.188
# [75, 20] loss: 0.161
# Accuracy of Grayscale Model after 75 epochs on test images: 79.69%
# [76, 10] loss: 0.155
# [76, 20] loss: 0.161
# Accuracy of Grayscale Model after 76 epochs on test images: 79.17%
# [77, 10] loss: 0.159
# [77, 20] loss: 0.126
# Accuracy of Grayscale Model after 77 epochs on test images: 79.69%
# [78, 10] loss: 0.135
# [78, 20] loss: 0.159
# Accuracy of Grayscale Model after 78 epochs on test images: 79.69%
# [79, 10] loss: 0.141
# [79, 20] loss: 0.170
# Accuracy of Grayscale Model after 79 epochs on test images: 79.69%
# [80, 10] loss: 0.133
# [80, 20] loss: 0.143
# Accuracy of Grayscale Model after 80 epochs on test images: 79.69%
# [81, 10] loss: 0.123
# [81, 20] loss: 0.161
# Accuracy of Grayscale Model after 81 epochs on test images: 80.21%
# [82, 10] loss: 0.129
# [82, 20] loss: 0.151
# Accuracy of Grayscale Model after 82 epochs on test images: 79.17%
# [83, 10] loss: 0.118
# [83, 20] loss: 0.112
# Accuracy of Grayscale Model after 83 epochs on test images: 80.21%
# [84, 10] loss: 0.117
# [84, 20] loss: 0.105
# Accuracy of Grayscale Model after 84 epochs on test images: 80.21%
# [85, 10] loss: 0.089
# [85, 20] loss: 0.103
# Accuracy of Grayscale Model after 85 epochs on test images: 80.21%
# [86, 10] loss: 0.105
# [86, 20] loss: 0.100
# Accuracy of Grayscale Model after 86 epochs on test images: 80.21%
# [87, 10] loss: 0.117
# [87, 20] loss: 0.089
# Accuracy of Grayscale Model after 87 epochs on test images: 80.73%
# [88, 10] loss: 0.091
# [88, 20] loss: 0.113
# Accuracy of Grayscale Model after 88 epochs on test images: 80.73%
# [89, 10] loss: 0.099
# [89, 20] loss: 0.099
# Accuracy of Grayscale Model after 89 epochs on test images: 80.73%
# [90, 10] loss: 0.061
# [90, 20] loss: 0.084
# Accuracy of Grayscale Model after 90 epochs on test images: 80.73%
